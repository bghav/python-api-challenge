# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
#Perform API Calls
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 617

# %%
# base url for OWM calls
base_url = "http://api.openweathermap.org/data/2.5/weather"

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count+=1
        record_count = 1
    # Create parameters.
    params = {"q": city, "units": "Imperial", "APPID": weather_api_key}
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of the Set {set_count} | {city[0]}")
    
    # Add 1 to the record count.
    record_count+=1

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(base_url, params=params).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_desc = str(city_weather["weather"][0]["description"])
        # Append the city information into city_data list.
        city_data.append({
            "City": city[0].title(),
            "Lat": city_lat,
            "Lng": city_lng,
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Current Description": city_weather_desc})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of the Set 1 | a
# Processing Record 2 of the Set 1 | k
# Processing Record 3 of the Set 1 | d
# Processing Record 4 of the Set 1 | b
# Processing Record 5 of the Set 1 | b
# Processing Record 6 of the Set 1 | p
# Processing Record 7 of the Set 1 | a
# Processing Record 8 of the Set 1 | m
# Processing Record 9 of the Set 1 | a
# Processing Record 10 of the Set 1 | b
# Processing Record 11 of the Set 1 | h
# Processing Record 12 of the Set 1 | o
# Processing Record 13 of the Set 1 | s
# Processing Record 14 of the Set 1 | u
# Processing Record 15 of the Set 1 | k
# Processing Record 16 of the Set 1 | c
# Processing Record 17 of the Set 1 | c
# Processing Record 18 of the Set 1 | v
# Processing Record 19 of the Set 1 | b
# Processing Record 20 of the Set 1 | n
# City not found. Skipping...
# Processing Record 21 of the Set 1 | p
# Processing Record 22 of the Set 1 | m
# Processing Record 23 of the Set 1 | p
# Processing Record 24 of the Set 1 | s
# Processing Record 25 of the Set 1 | h
# Processing Record 26 of the Set 1 | r
# Processing Record 27 of the Set 1 | h
# Processing Record 28 of the Set 1 | t
# City not found. Skipping...
# Processing Record 29 of the Set 1 | e
# Processing Record 30 of the Set 1 | m
# Processing Record 31 of the Set 1 | a
# Processing Record 32 of the Set 1 | h
# City not found. Skipping...
# Processing Record 33 of the Set 1 | m
# Processing Record 34 of the Set 1 | q
# Processing Record 35 of the Set 1 | f
# Processing Record 36 of the Set 1 | k
# Processing Record 37 of the Set 1 | g
# City not found. Skipping...
# Processing Record 38 of the Set 1 | p
# Processing Record 39 of the Set 1 | v
# City not found. Skipping...
# Processing Record 40 of the Set 1 | b
# City not found. Skipping...
# Processing Record 41 of the Set 1 | m
# Processing Record 42 of the Set 1 | i
# Processing Record 43 of the Set 1 | m
# Processing Record 44 of the Set 1 | s
# Processing Record 45 of the Set 1 | o
# Processing Record 46 of the Set 1 | m
# Processing Record 47 of the Set 1 | g
# Processing Record 48 of the Set 1 | n
# Processing Record 49 of the Set 1 | k
# Processing Record 50 of the Set 1 | s
# Processing Record 1 of the Set 2 | o
# Processing Record 2 of the Set 2 | d
# Processing Record 3 of the Set 2 | s
# City not found. Skipping...
# Processing Record 4 of the Set 2 | g
# Processing Record 5 of the Set 2 | b
# Processing Record 6 of the Set 2 | t
# Processing Record 7 of the Set 2 | c
# Processing Record 8 of the Set 2 | g
# Processing Record 9 of the Set 2 | m
# Processing Record 10 of the Set 2 | l
# Processing Record 11 of the Set 2 | p
# Processing Record 12 of the Set 2 | t
# Processing Record 13 of the Set 2 | a
# Processing Record 14 of the Set 2 | v
# Processing Record 15 of the Set 2 | k
# Processing Record 16 of the Set 2 | h
# Processing Record 17 of the Set 2 | f
# Processing Record 18 of the Set 2 | b
# Processing Record 19 of the Set 2 | p
# Processing Record 20 of the Set 2 | r
# Processing Record 21 of the Set 2 | k
# Processing Record 22 of the Set 2 | t
# Processing Record 23 of the Set 2 | q
# Processing Record 24 of the Set 2 | v
# Processing Record 25 of the Set 2 | t
# City not found. Skipping...
# Processing Record 26 of the Set 2 | f
# Processing Record 27 of the Set 2 | n
# City not found. Skipping...
# Processing Record 28 of the Set 2 | h
# Processing Record 29 of the Set 2 | a
# Processing Record 30 of the Set 2 | p
# Processing Record 31 of the Set 2 | m
# Processing Record 32 of the Set 2 | j
# Processing Record 33 of the Set 2 | j
# Processing Record 34 of the Set 2 | k
# Processing Record 35 of the Set 2 | l
# Processing Record 36 of the Set 2 | m
# Processing Record 37 of the Set 2 | w
# Processing Record 38 of the Set 2 | k
# Processing Record 39 of the Set 2 | l
# Processing Record 40 of the Set 2 | y
# Processing Record 41 of the Set 2 | l
# Processing Record 42 of the Set 2 | d
# Processing Record 43 of the Set 2 | a
# Processing Record 44 of the Set 2 | w
# Processing Record 45 of the Set 2 | e
# Processing Record 46 of the Set 2 | r
# Processing Record 47 of the Set 2 | m
# Processing Record 48 of the Set 2 | l
# Processing Record 49 of the Set 2 | s
# Processing Record 50 of the Set 2 | b
# Processing Record 1 of the Set 3 | c
# Processing Record 2 of the Set 3 | l
# Processing Record 3 of the Set 3 | k
# Processing Record 4 of the Set 3 | t
# City not found. Skipping...
# Processing Record 5 of the Set 3 | c
# Processing Record 6 of the Set 3 | n
# Processing Record 7 of the Set 3 | p
# Processing Record 8 of the Set 3 | d
# Processing Record 9 of the Set 3 | k
# Processing Record 10 of the Set 3 | s
# Processing Record 11 of the Set 3 | m
# City not found. Skipping...
# Processing Record 12 of the Set 3 | h
# Processing Record 13 of the Set 3 | a
# Processing Record 14 of the Set 3 | k
# Processing Record 15 of the Set 3 | m
# Processing Record 16 of the Set 3 | o
# Processing Record 17 of the Set 3 | p
# Processing Record 18 of the Set 3 | x
# Processing Record 19 of the Set 3 | n
# Processing Record 20 of the Set 3 | s
# Processing Record 21 of the Set 3 | n
# Processing Record 22 of the Set 3 | k
# Processing Record 23 of the Set 3 | p
# Processing Record 24 of the Set 3 | s
# Processing Record 25 of the Set 3 | h
# Processing Record 26 of the Set 3 | d
# City not found. Skipping...
# Processing Record 27 of the Set 3 | t
# Processing Record 28 of the Set 3 | p
# Processing Record 29 of the Set 3 | b
# Processing Record 30 of the Set 3 | x
# Processing Record 31 of the Set 3 | a
# Processing Record 32 of the Set 3 | p
# Processing Record 33 of the Set 3 | s
# Processing Record 34 of the Set 3 | n
# Processing Record 35 of the Set 3 | b
# City not found. Skipping...
# Processing Record 36 of the Set 3 | s
# Processing Record 37 of the Set 3 | c
# Processing Record 38 of the Set 3 | p
# Processing Record 39 of the Set 3 | a
# Processing Record 40 of the Set 3 | b
# Processing Record 41 of the Set 3 | b
# Processing Record 42 of the Set 3 | c
# Processing Record 43 of the Set 3 | l
# Processing Record 44 of the Set 3 | v
# Processing Record 45 of the Set 3 | n
# Processing Record 46 of the Set 3 | e
# Processing Record 47 of the Set 3 | r
# Processing Record 48 of the Set 3 | o
# Processing Record 49 of the Set 3 | h
# Processing Record 50 of the Set 3 | l
# Processing Record 1 of the Set 4 | h
# Processing Record 2 of the Set 4 | k
# Processing Record 3 of the Set 4 | i
# City not found. Skipping...
# Processing Record 4 of the Set 4 | h
# Processing Record 5 of the Set 4 | e
# Processing Record 6 of the Set 4 | a
# Processing Record 7 of the Set 4 | z
# Processing Record 8 of the Set 4 | e
# Processing Record 9 of the Set 4 | c
# Processing Record 10 of the Set 4 | m
# Processing Record 11 of the Set 4 | a
# City not found. Skipping...
# Processing Record 12 of the Set 4 | k
# Processing Record 13 of the Set 4 | u
# Processing Record 14 of the Set 4 | a
# Processing Record 15 of the Set 4 | p
# Processing Record 16 of the Set 4 | n
# Processing Record 17 of the Set 4 | a
# Processing Record 18 of the Set 4 | k
# Processing Record 19 of the Set 4 | w
# Processing Record 20 of the Set 4 | m
# Processing Record 21 of the Set 4 | n
# Processing Record 22 of the Set 4 | a
# Processing Record 23 of the Set 4 | c
# Processing Record 24 of the Set 4 | t
# Processing Record 25 of the Set 4 | m
# Processing Record 26 of the Set 4 | n
# Processing Record 27 of the Set 4 | t
# Processing Record 28 of the Set 4 | t
# Processing Record 29 of the Set 4 | s
# Processing Record 30 of the Set 4 | v
# Processing Record 31 of the Set 4 | a
# Processing Record 32 of the Set 4 | u
# Processing Record 33 of the Set 4 | b
# Processing Record 34 of the Set 4 | s
# Processing Record 35 of the Set 4 | s
# Processing Record 36 of the Set 4 | a
# Processing Record 37 of the Set 4 | h
# Processing Record 38 of the Set 4 | w
# Processing Record 39 of the Set 4 | m
# Processing Record 40 of the Set 4 | k
# Processing Record 41 of the Set 4 | m
# Processing Record 42 of the Set 4 | b
# Processing Record 43 of the Set 4 | c
# Processing Record 44 of the Set 4 | a
# Processing Record 45 of the Set 4 | a
# Processing Record 46 of the Set 4 | t
# City not found. Skipping...
# Processing Record 47 of the Set 4 | p
# Processing Record 48 of the Set 4 | a
# Processing Record 49 of the Set 4 | p
# Processing Record 50 of the Set 4 | k
# Processing Record 1 of the Set 5 | m
# City not found. Skipping...
# Processing Record 2 of the Set 5 | n
# Processing Record 3 of the Set 5 | h
# Processing Record 4 of the Set 5 | n
# Processing Record 5 of the Set 5 | h
# Processing Record 6 of the Set 5 | a
# Processing Record 7 of the Set 5 | z
# Processing Record 8 of the Set 5 | k
# Processing Record 9 of the Set 5 | s
# Processing Record 10 of the Set 5 | l
# Processing Record 11 of the Set 5 | g
# Processing Record 12 of the Set 5 | s
# City not found. Skipping...
# Processing Record 13 of the Set 5 | p
# Processing Record 14 of the Set 5 | l
# Processing Record 15 of the Set 5 | s
# Processing Record 16 of the Set 5 | t
# Processing Record 17 of the Set 5 | b
# Processing Record 18 of the Set 5 | l
# Processing Record 19 of the Set 5 | k
# Processing Record 20 of the Set 5 | k
# Processing Record 21 of the Set 5 | j
# Processing Record 22 of the Set 5 | k
# Processing Record 23 of the Set 5 | y
# Processing Record 24 of the Set 5 | m
# Processing Record 25 of the Set 5 | s
# Processing Record 26 of the Set 5 | m
# Processing Record 27 of the Set 5 | k
# Processing Record 28 of the Set 5 | m
# City not found. Skipping...
# Processing Record 29 of the Set 5 | k
# Processing Record 30 of the Set 5 | n
# Processing Record 31 of the Set 5 | v
# Processing Record 32 of the Set 5 | l
# Processing Record 33 of the Set 5 | p
# Processing Record 34 of the Set 5 | c
# Processing Record 35 of the Set 5 | y
# City not found. Skipping...
# Processing Record 36 of the Set 5 | b
# Processing Record 37 of the Set 5 | h
# Processing Record 38 of the Set 5 | b
# Processing Record 39 of the Set 5 | s
# Processing Record 40 of the Set 5 | l
# Processing Record 41 of the Set 5 | a
# City not found. Skipping...
# Processing Record 42 of the Set 5 | g
# Processing Record 43 of the Set 5 | c
# Processing Record 44 of the Set 5 | k
# Processing Record 45 of the Set 5 | m
# Processing Record 46 of the Set 5 | b
# Processing Record 47 of the Set 5 | p
# Processing Record 48 of the Set 5 | b
# Processing Record 49 of the Set 5 | w
# Processing Record 50 of the Set 5 | b
# Processing Record 1 of the Set 6 | o
# Processing Record 2 of the Set 6 | q
# Processing Record 3 of the Set 6 | o
# City not found. Skipping...
# Processing Record 4 of the Set 6 | m
# Processing Record 5 of the Set 6 | c
# Processing Record 6 of the Set 6 | t
# City not found. Skipping...
# Processing Record 7 of the Set 6 | h
# Processing Record 8 of the Set 6 | l
# Processing Record 9 of the Set 6 | t
# Processing Record 10 of the Set 6 | i
# Processing Record 11 of the Set 6 | l
# Processing Record 12 of the Set 6 | s
# Processing Record 13 of the Set 6 | t
# Processing Record 14 of the Set 6 | t
# Processing Record 15 of the Set 6 | v
# Processing Record 16 of the Set 6 | i
# Processing Record 17 of the Set 6 | r
# Processing Record 18 of the Set 6 | c
# Processing Record 19 of the Set 6 | p
# Processing Record 20 of the Set 6 | h
# Processing Record 21 of the Set 6 | a
# Processing Record 22 of the Set 6 | b
# City not found. Skipping...
# Processing Record 23 of the Set 6 | i
# Processing Record 24 of the Set 6 | a
# Processing Record 25 of the Set 6 | v
# Processing Record 26 of the Set 6 | a
# Processing Record 27 of the Set 6 | a
# Processing Record 28 of the Set 6 | k
# Processing Record 29 of the Set 6 | a
# City not found. Skipping...
# Processing Record 30 of the Set 6 | v
# Processing Record 31 of the Set 6 | g
# Processing Record 32 of the Set 6 | s
# Processing Record 33 of the Set 6 | c
# Processing Record 34 of the Set 6 | f
# Processing Record 35 of the Set 6 | b
# Processing Record 36 of the Set 6 | o
# Processing Record 37 of the Set 6 | b
# Processing Record 38 of the Set 6 | n
# Processing Record 39 of the Set 6 | i
# Processing Record 40 of the Set 6 | c
# Processing Record 41 of the Set 6 | h
# Processing Record 42 of the Set 6 | v
# Processing Record 43 of the Set 6 | d
# Processing Record 44 of the Set 6 | u
# City not found. Skipping...
# Processing Record 45 of the Set 6 | n
# Processing Record 46 of the Set 6 | p
# City not found. Skipping...
# Processing Record 47 of the Set 6 | e
# Processing Record 48 of the Set 6 | p
# Processing Record 49 of the Set 6 | l
# Processing Record 50 of the Set 6 | h
# Processing Record 1 of the Set 7 | b
# Processing Record 2 of the Set 7 | u
# Processing Record 3 of the Set 7 | a
# Processing Record 4 of the Set 7 | t
# City not found. Skipping...
# Processing Record 5 of the Set 7 | o
# Processing Record 6 of the Set 7 | b
# Processing Record 7 of the Set 7 | y
# Processing Record 8 of the Set 7 | c
# Processing Record 9 of the Set 7 | s
# Processing Record 10 of the Set 7 | u
# Processing Record 11 of the Set 7 | a
# City not found. Skipping...
# Processing Record 12 of the Set 7 | m
# Processing Record 13 of the Set 7 | w
# Processing Record 14 of the Set 7 | b
# Processing Record 15 of the Set 7 | s
# Processing Record 16 of the Set 7 | w
# City not found. Skipping...
# Processing Record 17 of the Set 7 | c
# Processing Record 18 of the Set 7 | t
# Processing Record 19 of the Set 7 | s
# City not found. Skipping...
# Processing Record 20 of the Set 7 | a
# Processing Record 21 of the Set 7 | c
# City not found. Skipping...
# Processing Record 22 of the Set 7 | o
# Processing Record 23 of the Set 7 | n
# Processing Record 24 of the Set 7 | i
# Processing Record 25 of the Set 7 | m
# Processing Record 26 of the Set 7 | p
# Processing Record 27 of the Set 7 | p
# Processing Record 28 of the Set 7 | v
# Processing Record 29 of the Set 7 | p
# Processing Record 30 of the Set 7 | m
# Processing Record 31 of the Set 7 | c
# Processing Record 32 of the Set 7 | f
# Processing Record 33 of the Set 7 | y
# Processing Record 34 of the Set 7 | w
# Processing Record 35 of the Set 7 | k
# Processing Record 36 of the Set 7 | o
# Processing Record 37 of the Set 7 | a
# Processing Record 38 of the Set 7 | h
# Processing Record 39 of the Set 7 | k
# Processing Record 40 of the Set 7 | a
# Processing Record 41 of the Set 7 | y
# Processing Record 42 of the Set 7 | m
# Processing Record 43 of the Set 7 | r
# City not found. Skipping...
# Processing Record 44 of the Set 7 | c
# Processing Record 45 of the Set 7 | l
# Processing Record 46 of the Set 7 | o
# Processing Record 47 of the Set 7 | n
# City not found. Skipping...
# Processing Record 48 of the Set 7 | s
# Processing Record 49 of the Set 7 | a
# Processing Record 50 of the Set 7 | e
# Processing Record 1 of the Set 8 | m
# Processing Record 2 of the Set 8 | b
# Processing Record 3 of the Set 8 | w
# Processing Record 4 of the Set 8 | d
# Processing Record 5 of the Set 8 | s
# Processing Record 6 of the Set 8 | n
# Processing Record 7 of the Set 8 | i
# Processing Record 8 of the Set 8 | g
# Processing Record 9 of the Set 8 | s
# Processing Record 10 of the Set 8 | m
# Processing Record 11 of the Set 8 | k
# City not found. Skipping...
# Processing Record 12 of the Set 8 | c
# Processing Record 13 of the Set 8 | v
# Processing Record 14 of the Set 8 | c
# Processing Record 15 of the Set 8 | a
# Processing Record 16 of the Set 8 | h
# Processing Record 17 of the Set 8 | c
# Processing Record 18 of the Set 8 | v
# Processing Record 19 of the Set 8 | k
# Processing Record 20 of the Set 8 | k
# Processing Record 21 of the Set 8 | n
# Processing Record 22 of the Set 8 | k
# Processing Record 23 of the Set 8 | s
# City not found. Skipping...
# Processing Record 24 of the Set 8 | b
# Processing Record 25 of the Set 8 | c
# Processing Record 26 of the Set 8 | s
# Processing Record 27 of the Set 8 | b
# Processing Record 28 of the Set 8 | g
# Processing Record 29 of the Set 8 | i
# Processing Record 30 of the Set 8 | c
# Processing Record 31 of the Set 8 | b
# Processing Record 32 of the Set 8 | h
# Processing Record 33 of the Set 8 | p
# Processing Record 34 of the Set 8 | k
# Processing Record 35 of the Set 8 | c
# Processing Record 36 of the Set 8 | b
# Processing Record 37 of the Set 8 | c
# Processing Record 38 of the Set 8 | b
# Processing Record 39 of the Set 8 | p
# Processing Record 40 of the Set 8 | c
# Processing Record 41 of the Set 8 | s
# Processing Record 42 of the Set 8 | t
# Processing Record 43 of the Set 8 | c
# Processing Record 44 of the Set 8 | b
# Processing Record 45 of the Set 8 | y
# Processing Record 46 of the Set 8 | n
# Processing Record 47 of the Set 8 | d
# Processing Record 48 of the Set 8 | q
# Processing Record 49 of the Set 8 | k
# Processing Record 50 of the Set 8 | b
# Processing Record 1 of the Set 9 | m
# Processing Record 2 of the Set 9 | k
# City not found. Skipping...
# Processing Record 3 of the Set 9 | r
# Processing Record 4 of the Set 9 | b
# Processing Record 5 of the Set 9 | g
# Processing Record 6 of the Set 9 | c
# Processing Record 7 of the Set 9 | n
# Processing Record 8 of the Set 9 | b
# Processing Record 9 of the Set 9 | p
# Processing Record 10 of the Set 9 | k
# Processing Record 11 of the Set 9 | g
# Processing Record 12 of the Set 9 | u
# Processing Record 13 of the Set 9 | a
# Processing Record 14 of the Set 9 | l
# Processing Record 15 of the Set 9 | s
# Processing Record 16 of the Set 9 | d
# Processing Record 17 of the Set 9 | l
# Processing Record 18 of the Set 9 | h
# Processing Record 19 of the Set 9 | p
# City not found. Skipping...
# Processing Record 20 of the Set 9 | r
# Processing Record 21 of the Set 9 | a
# Processing Record 22 of the Set 9 | m
# City not found. Skipping...
# Processing Record 23 of the Set 9 | d
# Processing Record 24 of the Set 9 | s
# Processing Record 25 of the Set 9 | g
# Processing Record 26 of the Set 9 | b
# Processing Record 27 of the Set 9 | t
# Processing Record 28 of the Set 9 | c
# Processing Record 29 of the Set 9 | s
# Processing Record 30 of the Set 9 | b
# Processing Record 31 of the Set 9 | s
# Processing Record 32 of the Set 9 | d
# Processing Record 33 of the Set 9 | g
# Processing Record 34 of the Set 9 | t
# Processing Record 35 of the Set 9 | n
# Processing Record 36 of the Set 9 | i
# Processing Record 37 of the Set 9 | m
# Processing Record 38 of the Set 9 | k
# Processing Record 39 of the Set 9 | b
# Processing Record 40 of the Set 9 | v
# Processing Record 41 of the Set 9 | k
# Processing Record 42 of the Set 9 | t
# Processing Record 43 of the Set 9 | k
# Processing Record 44 of the Set 9 | m
# City not found. Skipping...
# Processing Record 45 of the Set 9 | m
# Processing Record 46 of the Set 9 | b
# Processing Record 47 of the Set 9 | r
# Processing Record 48 of the Set 9 | c
# Processing Record 49 of the Set 9 | c
# City not found. Skipping...
# Processing Record 50 of the Set 9 | o
# Processing Record 1 of the Set 10 | p
# Processing Record 2 of the Set 10 | k
# Processing Record 3 of the Set 10 | p
# Processing Record 4 of the Set 10 | k
# Processing Record 5 of the Set 10 | t
# Processing Record 6 of the Set 10 | k
# Processing Record 7 of the Set 10 | a
# Processing Record 8 of the Set 10 | s
# Processing Record 9 of the Set 10 | s
# Processing Record 10 of the Set 10 | f
# Processing Record 11 of the Set 10 | b
# Processing Record 12 of the Set 10 | l
# Processing Record 13 of the Set 10 | b
# Processing Record 14 of the Set 10 | d
# Processing Record 15 of the Set 10 | c
# Processing Record 16 of the Set 10 | m
# Processing Record 17 of the Set 10 | p
# Processing Record 18 of the Set 10 | a
# City not found. Skipping...
# Processing Record 19 of the Set 10 | s
# City not found. Skipping...
# Processing Record 20 of the Set 10 | t
# Processing Record 21 of the Set 10 | u
# Processing Record 22 of the Set 10 | e
# Processing Record 23 of the Set 10 | a
# Processing Record 24 of the Set 10 | h
# Processing Record 25 of the Set 10 | l
# Processing Record 26 of the Set 10 | b
# Processing Record 27 of the Set 10 | a
# Processing Record 28 of the Set 10 | f
# Processing Record 29 of the Set 10 | t
# City not found. Skipping...
# Processing Record 30 of the Set 10 | u
# Processing Record 31 of the Set 10 | t
# City not found. Skipping...
# Processing Record 32 of the Set 10 | p
# Processing Record 33 of the Set 10 | i
# Processing Record 34 of the Set 10 | a
# Processing Record 35 of the Set 10 | s
# Processing Record 36 of the Set 10 | s
# Processing Record 37 of the Set 10 | q
# Processing Record 38 of the Set 10 | b
# Processing Record 39 of the Set 10 | k
# Processing Record 40 of the Set 10 | i
# Processing Record 41 of the Set 10 | h
# Processing Record 42 of the Set 10 | k
# Processing Record 43 of the Set 10 | t
# Processing Record 44 of the Set 10 | e
# Processing Record 45 of the Set 10 | a
# Processing Record 46 of the Set 10 | s
# Processing Record 47 of the Set 10 | l
# City not found. Skipping...
# Processing Record 48 of the Set 10 | p
# Processing Record 49 of the Set 10 | h
# Processing Record 50 of the Set 10 | c
# Processing Record 1 of the Set 11 | m
# Processing Record 2 of the Set 11 | u
# Processing Record 3 of the Set 11 | w
# Processing Record 4 of the Set 11 | j
# Processing Record 5 of the Set 11 | u
# Processing Record 6 of the Set 11 | z
# Processing Record 7 of the Set 11 | r
# Processing Record 8 of the Set 11 | n
# Processing Record 9 of the Set 11 | u
# Processing Record 10 of the Set 11 | a
# Processing Record 11 of the Set 11 | p
# Processing Record 12 of the Set 11 | v
# Processing Record 13 of the Set 11 | b
# Processing Record 14 of the Set 11 | p
# Processing Record 15 of the Set 11 | m
# Processing Record 16 of the Set 11 | n
# Processing Record 17 of the Set 11 | o
# Processing Record 18 of the Set 11 | v
# Processing Record 19 of the Set 11 | f
# Processing Record 20 of the Set 11 | c
# Processing Record 21 of the Set 11 | j
# Processing Record 22 of the Set 11 | m
# City not found. Skipping...
# Processing Record 23 of the Set 11 | k
# City not found. Skipping...
# Processing Record 24 of the Set 11 | e
# Processing Record 25 of the Set 11 | l
# Processing Record 26 of the Set 11 | v
# Processing Record 27 of the Set 11 | o
# City not found. Skipping...
# Processing Record 28 of the Set 11 | a
# Processing Record 29 of the Set 11 | m
# Processing Record 30 of the Set 11 | p
# Processing Record 31 of the Set 11 | e
# Processing Record 32 of the Set 11 | b
# Processing Record 33 of the Set 11 | g
# Processing Record 34 of the Set 11 | k
# Processing Record 35 of the Set 11 | k
# Processing Record 36 of the Set 11 | a
# Processing Record 37 of the Set 11 | c
# Processing Record 38 of the Set 11 | f
# Processing Record 39 of the Set 11 | t
# City not found. Skipping...
# Processing Record 40 of the Set 11 | i
# Processing Record 41 of the Set 11 | c
# Processing Record 42 of the Set 11 | m
# Processing Record 43 of the Set 11 | s
# Processing Record 44 of the Set 11 | a
# Processing Record 45 of the Set 11 | p
# Processing Record 46 of the Set 11 | b
# Processing Record 47 of the Set 11 | k
# City not found. Skipping...
# Processing Record 48 of the Set 11 | r
# Processing Record 49 of the Set 11 | j
# Processing Record 50 of the Set 11 | p
# Processing Record 1 of the Set 12 | k
# Processing Record 2 of the Set 12 | e
# Processing Record 3 of the Set 12 | m
# Processing Record 4 of the Set 12 | b
# Processing Record 5 of the Set 12 | n
# Processing Record 6 of the Set 12 | d
# Processing Record 7 of the Set 12 | s
# Processing Record 8 of the Set 12 | t
# Processing Record 9 of the Set 12 | k
# Processing Record 10 of the Set 12 | m
# Processing Record 11 of the Set 12 | v
# Processing Record 12 of the Set 12 | d
# Processing Record 13 of the Set 12 | t
# Processing Record 14 of the Set 12 | t
# Processing Record 15 of the Set 12 | c
# Processing Record 16 of the Set 12 | p
# Processing Record 17 of the Set 12 | g
# Processing Record 18 of the Set 12 | a
# Processing Record 19 of the Set 12 | s
# Processing Record 20 of the Set 12 | c
# Processing Record 21 of the Set 12 | s
# Processing Record 22 of the Set 12 | b
# Processing Record 23 of the Set 12 | n
# Processing Record 24 of the Set 12 | p
# Processing Record 25 of the Set 12 | k
# Processing Record 26 of the Set 12 | a
# Processing Record 27 of the Set 12 | v
# Processing Record 28 of the Set 12 | m
# Processing Record 29 of the Set 12 | m
# Processing Record 30 of the Set 12 | m
# Processing Record 31 of the Set 12 | v
# Processing Record 32 of the Set 12 | d
# Processing Record 33 of the Set 12 | p
# Processing Record 34 of the Set 12 | d
# Processing Record 35 of the Set 12 | k
# Processing Record 36 of the Set 12 | u
# City not found. Skipping...
# Processing Record 37 of the Set 12 | h
# City not found. Skipping...
# Processing Record 38 of the Set 12 | p
# Processing Record 39 of the Set 12 | k
# Processing Record 40 of the Set 12 | f
# Processing Record 41 of the Set 12 | s
# Processing Record 42 of the Set 12 | k
# Processing Record 43 of the Set 12 | k
# Processing Record 44 of the Set 12 | g
# Processing Record 45 of the Set 12 | t
# Processing Record 46 of the Set 12 | t
# Processing Record 47 of the Set 12 | s
# Processing Record 48 of the Set 12 | h
# Processing Record 49 of the Set 12 | t
# Processing Record 50 of the Set 12 | a
# Processing Record 1 of the Set 13 | k
# Processing Record 2 of the Set 13 | c
# Processing Record 3 of the Set 13 | b
# Processing Record 4 of the Set 13 | y
# Processing Record 5 of the Set 13 | v
# Processing Record 6 of the Set 13 | b
# Processing Record 7 of the Set 13 | t
# Processing Record 8 of the Set 13 | k
# Processing Record 9 of the Set 13 | g
# Processing Record 10 of the Set 13 | s
# Processing Record 11 of the Set 13 | a
# Processing Record 12 of the Set 13 | k
# Processing Record 13 of the Set 13 | h
# Processing Record 14 of the Set 13 | g
# Processing Record 15 of the Set 13 | t
# Processing Record 16 of the Set 13 | b
# Processing Record 17 of the Set 13 | p
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# create a data frame from cities, lat and lon
weather_dict = {
    "city": cities,
    "latlon": lat_lngs,
    "location":city_data
}
weather_data = pd.DataFrame(weather_dict)
weather_data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-5f2f1f0e0efe> in <module>
#       5     "location":city_data
#       6 }
# ----> 7 weather_data = pd.DataFrame(weather_dict)
#       8 weather_data
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     466
#     467         elif isinstance(data, dict):
# --> 468             mgr = init_dict(data, index, columns, dtype=dtype)
#     469         elif isinstance(data, ma.MaskedArray):
#     470             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     281             arr if not is_datetime64tz_dtype(arr) else arr.copy() for arr in arrays
#     282         ]
# --> 283     return arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     284
#     285
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in arrays_to_mgr(arrays, arr_names, index, columns, dtype, verify_integrity)
#      76         # figure out the index, if necessary
#      77         if index is None:
# ---> 78             index = extract_index(arrays)
#      79         else:
#      80             index = ensure_index(index)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in extract_index(data)
#     395             lengths = list(set(raw_lengths))
#     396             if len(lengths) > 1:
# --> 397                 raise ValueError("arrays must all be same length")
#     398
#     399             if have_dicts:
#
# ValueError: arrays must all be same length
